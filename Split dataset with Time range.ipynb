# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('BARC.csv',encoding = "cp1252")

# %%
df.tail(10)
# Out:
#        Unnamed: 0        Date  Time   SO2  NO  NO2  NOX     CO     O3    PM25  \
# 21878       21878  31/03/2019    15  1.90 NaN  NaN  NaN  0.647  45.47   55.82
# 21879       21879  31/03/2019    16  1.58 NaN  NaN  NaN  0.697  20.14   67.14
# 21880       21880  31/03/2019    17  1.80 NaN  NaN  NaN  0.673  30.23   72.62
# 21881       21881  31/03/2019    18  1.80 NaN  NaN  NaN  0.671  41.32   74.12
# 21882       21882  31/03/2019    19   NaN NaN  NaN  NaN    NaN    NaN     NaN
# 21883       21883  31/03/2019    20   NaN NaN  NaN  NaN    NaN    NaN     NaN
# 21884       21884  31/03/2019    21  2.02 NaN  NaN  NaN  1.234  15.19     NaN
# 21885       21885  31/03/2019    22  2.52 NaN  NaN  NaN  1.261   1.80     NaN
# 21886       21886  31/03/2019    23  2.36 NaN  NaN  NaN  1.277   2.41  499.22
# 21887       21887  31/03/2019     0  1.95 NaN  NaN  NaN  1.197   0.53  274.24
#
#          PM10  Temperature  RH  Solar Rad  BP  Rain
# 21878  160.85          NaN NaN        NaN NaN   NaN
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Date            object
# Time             int64
# SO2            float64
# NO             float64
# NO2            float64
# NOX            float64
# CO             float64
# O3             float64
# PM25           float64
# PM10           float64
# Temperature    float64
# RH             float64
# Solar Rad      float64
# BP             float64
# Rain           float64
# dtype: object

# %%
from datetime import datetime
#df['Date']=pd.to_datetime(df['Date'])
time=pd.to_datetime(df['Date'])

# %%
df['Date']=time
df['Year']=df.Date.dt.year
df['Month']=df.Date.dt.month
df['Day']=df.Date.dt.day
df['Week_Day']=df.Date.dt.weekday_name

# %%
df.head()
# Out:
#    Unnamed: 0       Date  Time   SO2  NO  NO2  NOX  CO    O3  PM25   PM10  \
# 0           0 2016-10-01     1  3.98 NaN  NaN  NaN NaN  0.80   NaN  55.13
# 1           1 2016-10-01     2  2.83 NaN  NaN  NaN NaN  1.23   NaN  34.41
# 2           2 2016-10-01     3  1.79 NaN  NaN  NaN NaN  0.95   NaN  19.04
# 3           3 2016-10-01     4  0.83 NaN  NaN  NaN NaN  0.78   NaN  12.59
# 4           4 2016-10-01     5  0.36 NaN  NaN  NaN NaN  0.92   NaN   9.20
#
#    Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day  Week_Day
# 0        26.59  84.03        NaN NaN  1.20  2016     10    1  Saturday
# 1        26.61  86.57        NaN NaN  2.30  2016     10    1  Saturday
# 2        27.15  88.10        NaN NaN  1.61  2016     10    1  Saturday
# 3        27.05  89.71        NaN NaN   NaN  2016     10    1  Saturday
# 4        26.45  91.11        NaN NaN  1.44  2016     10    1  Saturday

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Date           datetime64[ns]
# Time                    int64
# SO2                   float64
# NO                    float64
# NO2                   float64
# NOX                   float64
# CO                    float64
# O3                    float64
# PM25                  float64
# PM10                  float64
# Temperature           float64
# RH                    float64
# Solar Rad             float64
# BP                    float64
# Rain                  float64
# Year                    int64
# Month                   int64
# Day                     int64
# Week_Day               object
# dtype: object

# %%
winter=pd.DataFrame()

# %%
mask = (df['Date'] > '2016-10-15') & (df['Date'] <= '2017-3-1')
winter=df.loc[mask]

# %%
winter.head(1)
# Out:
#      Unnamed: 0       Date  Time  SO2  NO  NO2  NOX   CO    O3  PM25    PM10  \
# 360         360 2016-10-16     1  8.4 NaN  NaN  NaN  1.9  0.62   NaN  118.18
#
#      Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day Week_Day
# 360        26.21  57.75        NaN NaN  0.18  2016     10   16   Sunday

# %%
df2=pd.DataFrame()

# %%
mask = (df['Date'] > '2017-10-15') & (df['Date'] <= '2018-3-1')
df2=df.loc[mask]

# %%
df2.head(1)
# Out:
#       Unnamed: 0       Date  Time    SO2  NO  NO2  NOX    CO  O3  PM25  PM10  \
# 2448        2448 2017-11-01     1  18.11 NaN  NaN  NaN  0.92 NaN   NaN   NaN
#
#       Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day   Week_Day
# 2448        28.76  61.28        NaN NaN   NaN  2017     11    1  Wednesday

# %%
winter=winter.append(df2)

# %%
winter.head(2)
# Out:
#      Unnamed: 0       Date  Time   SO2  NO  NO2  NOX    CO    O3  PM25  \
# 360         360 2016-10-16     1  8.40 NaN  NaN  NaN  1.90  0.62   NaN
# 361         361 2016-10-16     2  8.07 NaN  NaN  NaN  1.64  0.81   NaN
#
#        PM10  Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day  \
# 360  118.18        26.21  57.75        NaN NaN  0.18  2016     10   16
# 361  111.53        26.38  59.54        NaN NaN  3.30  2016     10   16
#
#     Week_Day
# 360   Sunday
# 361   Sunday

# %%
df3=pd.DataFrame()

# %%
mask = (df['Date'] > '2018-10-15') & (df['Date'] <= '2019-3-15')
df3=df.loc[mask]

# %%
winter=winter.append(df3)

# %%
winter.tail(1000)
# Out:
#        Unnamed: 0       Date  Time   SO2      NO    NO2     NOX    CO     O3  \
# 20072       20072 2019-01-15     9  1.97  191.34  27.03  191.34  0.68   1.78
# 20073       20073 2019-01-15    10  2.04  204.94  31.52  204.94  0.72   2.06
# 20074       20074 2019-01-15    11  1.94  191.06  36.73  191.06  0.93   2.68
# 20075       20075 2019-01-15    12  2.21  162.20  45.48  162.20  0.77   3.81
# 20076       20076 2019-01-15    13  2.46  143.33  43.09  143.33  0.75  18.35
# 20077       20077 2019-01-15    14  3.08  143.50  39.06  143.50  0.66  14.24
# 20078       20078 2019-01-15    15  2.64  106.45  48.10  106.45  0.56  11.92
# 20079       20079 2019-01-15    16  2.56   99.52  41.63   99.52  0.45   3.83
# 20080       20080 2019-01-15    17  1.27   92.78  32.02   92.78  0.35   4.49
# 20081       20081 2019-01-15    18  0.70   74.09  35.59   74.09  0.67   3.99
# 20082       20082 2019-01-15    19  0.54   80.18  37.86   80.18  0.61   2.12
# ...

# %%
summer=pd.DataFrame()

# %%
mask = (df['Date'] > '2017-3-15') & (df['Date'] <= '2017-7-30')
summer=df.loc[mask]

# %%
df2=pd.DataFrame()

# %%
mask = (df['Date'] > '2018-3-15') & (df['Date'] <= '2018-7-30')
df2=df2.loc[mask]

# %%
summer=summer.append(df2)

# %%
summer.head()
# Out:
#       Unnamed: 0       Date  Time  SO2  NO  NO2  NOX  CO  O3  PM25  PM10  \
# 2280        2280 2017-04-01     1  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2281        2281 2017-04-01     2  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2282        2282 2017-04-01     3  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2283        2283 2017-04-01     4  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2284        2284 2017-04-01     5  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
#
#       Temperature  RH  Solar Rad  BP  Rain  Year  Month  Day  Week_Day
# 2280          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2281          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2282          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2283          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2284          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday

# %%
summer=summer.append(df2)

# %%
summer.shape
# Out:
# (3576, 20)

# %%
winter.shape
# Out:
# (9288, 20)

# %%
#winter.to_csv('winter.csv')

# %%
summer.head()
# Out:
#       Unnamed: 0       Date  Time  SO2  NO  NO2  NOX  CO  O3  PM25  PM10  \
# 2280        2280 2017-04-01     1  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2281        2281 2017-04-01     2  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2282        2282 2017-04-01     3  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2283        2283 2017-04-01     4  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
# 2284        2284 2017-04-01     5  NaN NaN  NaN  NaN NaN NaN   NaN   NaN
#
#       Temperature  RH  Solar Rad  BP  Rain  Year  Month  Day  Week_Day
# 2280          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2281          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2282          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2283          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday
# 2284          NaN NaN        NaN NaN   NaN  2017      4    1  Saturday

# %%
winter.head()
# Out:
#      Unnamed: 0       Date  Time   SO2  NO  NO2  NOX    CO    O3  PM25  \
# 360         360 2016-10-16     1  8.40 NaN  NaN  NaN  1.90  0.62   NaN
# 361         361 2016-10-16     2  8.07 NaN  NaN  NaN  1.64  0.81   NaN
# 362         362 2016-10-16     3  5.53 NaN  NaN  NaN  1.67  1.83   NaN
# 363         363 2016-10-16     4  0.76 NaN  NaN  NaN  2.00  0.82   NaN
# 364         364 2016-10-16     5   NaN NaN  NaN  NaN  1.56  0.97   NaN
#
#        PM10  Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day  \
# 360  118.18        26.21  57.75        NaN NaN  0.18  2016     10   16
# 361  111.53        26.38  59.54        NaN NaN  3.30  2016     10   16
# 362  101.82        26.65  65.40        NaN NaN  1.05  2016     10   16
# 363   96.07        26.52  70.31        NaN NaN  0.57  2016     10   16
# 364   85.69        26.23  71.66        NaN NaN   NaN  2016     10   16
#
#     Week_Day
# 360   Sunday
# 361   Sunday
# 362   Sunday
# 363   Sunday
# 364   Sunday

# %%
summer.to_csv('B_summer.csv')

# %%
winter.to_csv('B_winter.csv')
