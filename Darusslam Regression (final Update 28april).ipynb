# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('B_winter.csv',encoding = "cp1252")

# %%
print(df.head())
print(df.columns)
# Out:
#          Date  Time   SO2  NO  NO2  NOX    CO    O3  PM25    PM10  \
# 0  2016-10-16     1  8.40 NaN  NaN  NaN  1.90  0.62   NaN  118.18
# 1  2016-10-16     2  8.07 NaN  NaN  NaN  1.64  0.81   NaN  111.53
# 2  2016-10-16     3  5.53 NaN  NaN  NaN  1.67  1.83   NaN  101.82
# 3  2016-10-16     4  0.76 NaN  NaN  NaN  2.00  0.82   NaN   96.07
# 4  2016-10-16     5   NaN NaN  NaN  NaN  1.56  0.97   NaN   85.69
#
#    Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day Week_Day
# 0        26.21  57.75        NaN NaN  0.18  2016     10   16   Sunday
# 1        26.38  59.54        NaN NaN  3.30  2016     10   16   Sunday
# 2        26.65  65.40        NaN NaN  1.05  2016     10   16   Sunday
# 3        26.52  70.31        NaN NaN  0.57  2016     10   16   Sunday
# 4        26.23  71.66        NaN NaN   NaN  2016     10   16   Sunday
# Index(['Date', 'Time', 'SO2', 'NO', 'NO2', 'NOX', 'CO', 'O3', 'PM25', 'PM10',
#        'Temperature', 'RH', 'Solar Rad', 'BP', 'Rain', 'Year', 'Month', 'Day',
#        'Week_Day'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date            object
# Time             int64
# SO2            float64
# NO             float64
# NO2            float64
# NOX            float64
# CO             float64
# O3             float64
# PM25           float64
# PM10           float64
# Temperature    float64
# RH             float64
# Solar Rad      float64
# BP             float64
# Rain           float64
# Year             int64
# Month            int64
# Day              int64
# Week_Day        object
# dtype: object

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = [16,9]

# %%
df.shape
# Out:
# (9288, 19)

# %%
from datetime import datetime
#df['Date']=pd.to_datetime(df['Date'])
time=pd.to_datetime(df['Date'])

# %%
tf=pd.DataFrame()

# %%
tf['DateTime']=time
df['Year']=tf.DateTime.dt.year
df['Month']=tf.DateTime.dt.month
df['Day']=tf.DateTime.dt.day
df['Week_Day']=tf.DateTime.dt.weekday_name

# %%
df.head()
# Out:
#          Date  Time   SO2  NO  NO2  NOX    CO    O3  PM25    PM10  \
# 0  2016-10-16     1  8.40 NaN  NaN  NaN  1.90  0.62   NaN  118.18
# 1  2016-10-16     2  8.07 NaN  NaN  NaN  1.64  0.81   NaN  111.53
# 2  2016-10-16     3  5.53 NaN  NaN  NaN  1.67  1.83   NaN  101.82
# 3  2016-10-16     4  0.76 NaN  NaN  NaN  2.00  0.82   NaN   96.07
# 4  2016-10-16     5   NaN NaN  NaN  NaN  1.56  0.97   NaN   85.69
#
#    Temperature     RH  Solar Rad  BP  Rain  Year  Month  Day Week_Day
# 0        26.21  57.75        NaN NaN  0.18  2016     10   16   Sunday
# 1        26.38  59.54        NaN NaN  3.30  2016     10   16   Sunday
# 2        26.65  65.40        NaN NaN  1.05  2016     10   16   Sunday
# 3        26.52  70.31        NaN NaN  0.57  2016     10   16   Sunday
# 4        26.23  71.66        NaN NaN   NaN  2016     10   16   Sunday

# %%
df.dtypes
# Out:
# Date            object
# Time             int64
# SO2            float64
# NO             float64
# NO2            float64
# NOX            float64
# CO             float64
# O3             float64
# PM25           float64
# PM10           float64
# Temperature    float64
# RH             float64
# Solar Rad      float64
# BP             float64
# Rain           float64
# Year             int64
# Month            int64
# Day              int64
# Week_Day        object
# dtype: object

# %%
x=df['Day']
y=df['PM25']
plt.scatter(x,y)
plt.xlabel("Time")
plt.ylabel("PM2.5")
plt.title("PM2.5 OVER TIME")
plt.show()

# %%
x=df['Week_Day']
y=df['PM25']
plt.scatter(x,y)
plt.xlabel("Week_Day")
plt.ylabel("PM2.5")
plt.title("PM2.5 OVER Weekened")
plt.show()

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Date              0
# Time              0
# SO2            2184
# NO             6352
# NO2            6195
# NOX            6284
# CO             2554
# O3             1021
# PM25           2980
# PM10           2070
# Temperature    2730
# RH             2786
# Solar Rad      9288
# BP             7984
# Rain           3535
# Year              0
# Month             0
# Day               0
# Week_Day          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 55963

# %%
df["Rain"]=df["Rain"].replace(np.NaN,0)

# %%
df.isnull().sum()  #Done
# Out:
# Date              0
# Time              0
# SO2            2184
# NO             6352
# NO2            6195
# NOX            6284
# CO             2554
# O3             1021
# PM25           2980
# PM10           2070
# Temperature    2730
# RH             2786
# Solar Rad      9288
# BP             7984
# Rain              0
# Year              0
# Month             0
# Day               0
# Week_Day          0
# dtype: int64

# %%
df["SO2"]=df["SO2"].interpolate(limit_direction='both')
df["NO"]=df["NO"].interpolate(limit_direction='both')
df["NO2"]=df["NO2"].interpolate(limit_direction='both')
df["NOX"]=df["NOX"].interpolate(limit_direction='both')
df["CO"]=df["CO"].interpolate(limit_direction='both')
df["O3"]=df["O3"].interpolate(limit_direction='both')
df["PM25"]=df["PM25"].interpolate(limit_direction='both')
df["PM10"]=df["PM10"].interpolate(limit_direction='both')
df["Temperature"]=df["Temperature"].interpolate(limit_direction='both')
df["RH"]=df["RH"].interpolate(limit_direction='both')
df["Solar Rad"]=df["Solar Rad"].interpolate(limit_direction='both')
df["BP"]=df["BP"].interpolate(limit_direction='both')

# %%
df.isnull().sum()
# Out:
# Date              0
# Time              0
# SO2               0
# NO                0
# NO2               0
# NOX               0
# CO                0
# O3                0
# PM25              0
# PM10              0
# Temperature       0
# RH                0
# Solar Rad      9288
# BP                0
# Rain              0
# Year              0
# Month             0
# Day               0
# Week_Day          0
# dtype: int64

# %%
#df=df.drop(columns=['CO']) #only for D_summer
df=df.drop(columns=['Solar Rad']) #only for BARC,B_winter
#df=df.drop(columns=['Solar Rad','BP']) #only for B_summer

# %%
x=df['Time']
y=df['PM25']
plt.scatter(x,y)
plt.xlabel("Time")
plt.ylabel("PM2.5")
plt.title("PM2.5 OVER TIME")
plt.show()

# %%
x=df['Week_Day']
y=df['PM25']
plt.scatter(x,y)
plt.xlabel("Weekened")
plt.ylabel("PM2.5")
plt.title("PM2.5 OVER Weekdays")
plt.show()

# %%
def t_series(start,end):
    time_series=df[['Date','PM25']][(df['Date'] >= start) & (df['Date'] <= end)]
    x=time_series.Date
    y=time_series.PM25
    plt.plot(x,y)
    plt.xlabel('Date')
    plt.ylabel('PM2.5 Values')
    plt.title('PM2.5 Time Series')
    return plt.show();

# %%
#t_series('2016','2019')

# %%
df.describe()
# Out:
#               Time          SO2           NO          NO2          NOX  \
# count  9288.000000  9288.000000  9288.000000  9288.000000  9288.000000
# mean     11.500000    16.156450    57.547449    41.204208    87.763566
# std       6.922559    28.827445    55.171552    27.786768    58.217650
# min       0.000000     0.050000     0.050000     0.060000     0.060000
# 25%       5.750000     2.220000    31.240331    20.545013    50.205508
# 50%      11.500000     4.388934    33.440000    34.911412    85.410000
# 75%      17.250000    15.872500    77.413279    73.980000   106.970879
# max      23.000000   279.100000   399.300000   373.230000   398.670000
#
#                 CO           O3         PM25         PM10  Temperature  \
# count  9288.000000  9288.000000  9288.000000  9288.000000  9288.000000
# mean      1.405953    15.996737   112.282600   171.757838    26.510273
# std       1.788318    26.439084    90.442015   129.989165     3.832620
# min       0.050000     0.050000     4.140000     9.340000    12.340000
# 25%       0.369037     2.507500    25.115000    91.308856    24.450000
# 50%       0.780000     5.060000   101.415000   157.685000    26.600000
# 75%       1.810000    10.670000   158.362925   218.900000    28.400000
# max      14.760000   100.860000   496.890000   991.150000    39.770000
#
#                 RH           BP         Rain         Year        Month  \
# count  9288.000000  9288.000000  9288.000000  9288.000000  9288.000000
# mean     48.336304   982.917127     0.493229  2017.423773     7.648579
# std      19.810300    14.854830     0.793532     0.965209     4.732411
# min       9.530000   976.120000     0.000000  2016.000000     1.000000
# 25%      32.091651   976.120000     0.000000  2017.000000     2.000000
# 50%      45.770000   976.120000     0.170000  2017.000000    11.000000
# 75%      64.030000   976.120000     0.732500  2018.000000    12.000000
# max      98.710000  1025.200000    20.960000  2019.000000    12.000000
#
#                Day
# count  9288.000000
# mean     16.728682
# std       8.968199
# min       1.000000
# 25%      10.000000
# 50%      18.000000
# 75%      24.000000
# max      31.000000

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
df['day_week_cat'] = df.Week_Day.astype("category").cat.codes #Catagory week_day like encoding

# %%
df = df.drop(['Week_Day'], axis=1) #after that no need of Week_day

# %%
df.head()
# Out:
#          Date  Time    SO2     NO    NO2    NOX    CO    O3   PM25    PM10  \
# 0  2016-10-16     1  8.400  33.44  73.98  85.41  1.90  0.62  16.55  118.18
# 1  2016-10-16     2  8.070  33.44  73.98  85.41  1.64  0.81  16.55  111.53
# 2  2016-10-16     3  5.530  33.44  73.98  85.41  1.67  1.83  16.55  101.82
# 3  2016-10-16     4  0.760  33.44  73.98  85.41  2.00  0.82  16.55   96.07
# 4  2016-10-16     5  0.945  33.44  73.98  85.41  1.56  0.97  16.55   85.69
#
#    Temperature     RH      BP  Rain  Year  Month  Day  day_week_cat
# 0        26.21  57.75  976.12  0.18  2016     10   16             3
# 1        26.38  59.54  976.12  3.30  2016     10   16             3
# 2        26.65  65.40  976.12  1.05  2016     10   16             3
# 3        26.52  70.31  976.12  0.57  2016     10   16             3
# 4        26.23  71.66  976.12  0.00  2016     10   16             3

# %%
from IPython.display import Image
Image(filename='pic.jpg')

# %%
df = df.drop(['Date'], axis=1)

# %%
df.head()
# Out:
#    Time    SO2     NO    NO2    NOX    CO    O3   PM25    PM10  Temperature  \
# 0     1  8.400  33.44  73.98  85.41  1.90  0.62  16.55  118.18        26.21
# 1     2  8.070  33.44  73.98  85.41  1.64  0.81  16.55  111.53        26.38
# 2     3  5.530  33.44  73.98  85.41  1.67  1.83  16.55  101.82        26.65
# 3     4  0.760  33.44  73.98  85.41  2.00  0.82  16.55   96.07        26.52
# 4     5  0.945  33.44  73.98  85.41  1.56  0.97  16.55   85.69        26.23
#
#       RH      BP  Rain  Year  Month  Day  day_week_cat
# 0  57.75  976.12  0.18  2016     10   16             3
# 1  59.54  976.12  3.30  2016     10   16             3
# 2  65.40  976.12  1.05  2016     10   16             3
# 3  70.31  976.12  0.57  2016     10   16             3
# 4  71.66  976.12  0.00  2016     10   16             3

# %% [markdown]
# now finally remove all the nul value contains rows

# %% [markdown]
# df['hr_sin'] = np.sin(df.Time*(2.*np.pi/24))
# df['hr_cos'] = np.cos(df.Time*(2.*np.pi/24))
# df['month_sin'] = np.sin((df.Month-1)*(2.*np.pi/12))
# df['month_cos'] = np.cos((df.Month-1)*(2.*np.pi/12))

# %% [markdown]
# df.plot.scatter('hr_sin','hr_cos').set_aspect('equal')
# df.plot.scatter('month_sin','month_cos').set_aspect('equal')
# plt.show()

# %% [markdown]
# df = df.drop(['Month', 'Time'], axis=1)

# %%
y = df['PM25']

# %%
X = df.drop(['PM25'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=1234)

# %%
X_train.shape, y_train.shape
# Out:
# ((6501, 16), (6501,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2787, 16), (2787,))

# %%
X.columns
# Out:
# Index(['Time', 'SO2', 'NO', 'NO2', 'NOX', 'CO', 'O3', 'PM10', 'Temperature',
#        'RH', 'BP', 'Rain', 'Year', 'Month', 'Day', 'day_week_cat'],
#       dtype='object')

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create linear regression object
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Make predictions using the testing set
lin_pred = regr.predict(X_test)

# %%
linear_regression_score = regr.score(X_test, y_test)
linear_regression_score
# Out:
# 0.6260885371594336

# %%
from math import sqrt
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, lin_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, lin_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, lin_pred))
# Out:
# Coefficients:
#  [-0.48660225 -0.07262364  0.1917636  -0.55676735  0.05273245  1.10099808
#  -0.18535756  0.39069972  2.31256607  0.02025692 -0.69414582  5.20558647
#   1.99037768 -4.66771418  0.28017453 -2.1303644 ]
# Root mean squared error: 55.09
# Mean absolute error: 37.15
# R-squared: 0.63

# %%
plt.scatter(y_test, lin_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Linear Regression Predicted vs Actual')
plt.show()

# %% [markdown]
# Neural Network Regression

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Create MLPRegressor object
mlp = MLPRegressor()

# %%
# Train the model using the training sets
mlp.fit(X_train, y_train)
# Out:
# /home/shaonsani/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
# Score the model
neural_network_regression_score = mlp.score(X_test, y_test)
neural_network_regression_score
# Out:
# 0.7317935716936282

# %%
# Make predictions using the testing set
nnr_pred = mlp.predict(X_test)

# %%
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, nnr_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, nnr_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, nnr_pred))
# Out:
# Root mean squared error: 46.66
# Mean absolute error: 29.45
# R-squared: 0.73

# %%
plt.scatter(y_test, nnr_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Neural Network Regression Predicted vs Actual')
plt.show()

# %% [markdown]
# Decision Forest Regression¶

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# Create Random Forrest Regressor object
regr_rf = RandomForestRegressor(n_estimators=200, random_state=1234)

# %%
# Train the model using the training sets
regr_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#            oob_score=False, random_state=1234, verbose=0, warm_start=False)

# %%
# Score the model
decision_forest_score = regr_rf.score(X_test, y_test)
decision_forest_score
# Out:
# 0.9284337349870612

# %%
# Make predictions using the testing set
regr_rf_pred = regr_rf.predict(X_test)

# %%
# The mean squared error
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, regr_rf_pred)))
# The absolute squared error
print("Mean absolute error: %.2f"
      % mean_absolute_error(y_test, regr_rf_pred))
# Explained variance score: 1 is perfect prediction
print('R-squared: %.2f' % r2_score(y_test, regr_rf_pred))
# Out:
# Root mean squared error: 24.10
# Mean absolute error: 12.03
# R-squared: 0.93

# %%
X.columns
# Out:
# Index(['Time', 'SO2', 'NO', 'NO2', 'NOX', 'CO', 'O3', 'PM10', 'Temperature',
#        'RH', 'BP', 'Rain', 'Year', 'Month', 'Day', 'day_week_cat'],
#       dtype='object')

# %%
features = X.columns
importances = regr_rf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features[indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
plt.scatter(y_test, regr_rf_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Decision Forest Predicted vs Actual')
plt.show()

# %% [markdown]
# Lasso

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
# Score the model
lasso_score = lasso.score(X_test, y_test)
lasso_score
# Out:
# 0.6263009527009556

# %%
# Make predictions using the testing set
lasso_pred = lasso.predict(X_test)

# %%
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, lasso_pred)))
# Out:
# Root mean squared error: 55.08

# %%
plt.scatter(y_test, lasso_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Lasso Predicted vs Actual')
plt.show()

# %% [markdown]
# XGBOOST

# %%
from xgboost.sklearn import XGBRegressor

#Fitting XGB regressor 
xboost = XGBRegressor(n_estimators=200)

# %%
df.Time = df.Time.astype(int)

# %%
df.dtypes
# Out:
# Time              int64
# SO2             float64
# NO              float64
# NO2             float64
# NOX             float64
# CO              float64
# O3              float64
# PM25            float64
# PM10            float64
# Temperature     float64
# RH              float64
# BP              float64
# Rain            float64
# Year              int64
# Month             int64
# Day               int64
# day_week_cat       int8
# dtype: object

# %%
xboost.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=200,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
xgb_score = xboost.score(X_test, y_test)
xgb_score
# Out:
# 0.8560837021683164

# %%
#Predict 
xboost_pred = xboost.predict(X_test)

# %%
print("Root mean squared error: %.2f"
      % sqrt(mean_squared_error(y_test, xboost_pred)))
# Out:
# Root mean squared error: 34.18

# %%
plt.scatter(y_test, xboost_pred)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('XGBoost Predicted vs Actual')
plt.show()

# %%
print("Scores:")
print("Linear regression score: ", linear_regression_score)
print("Neural network regression score: ", neural_network_regression_score)
print("Lasso regression score: ", lasso_score)
print("Decision forest score: ", decision_forest_score)
print("XGBoost score:", xgb_score)
print("\n")
print("RMSE:")
print("Linear regression RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, lin_pred)))
print("Neural network RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, nnr_pred)))
print("Lasso RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, lasso_pred)))
print("Decision forest RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, regr_rf_pred)))
print("XGBoost RMSE: %.2f"
      % sqrt(mean_squared_error(y_test, xboost_pred)))
# Out:
# Scores:
# Linear regression score:  0.6260885371594336
# Neural network regression score:  0.7317935716936282
# Lasso regression score:  0.6263009527009556
# Decision forest score:  0.9284337349870612
# XGBoost score: 0.8560837021683164
#
#
# RMSE:
# Linear regression RMSE: 55.09
# Neural network RMSE: 46.66
# Lasso RMSE: 55.08
# Decision forest RMSE: 24.10
# XGBoost RMSE: 34.18
